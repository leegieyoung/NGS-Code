# %%
a=[]
b=''
for A in range(1,102):
    a.append("PBS_")
    a.append(str(A))
    a.append(".sh")
    b += ''.join(a)
    a=[]
    change_PBS=[]
    raw_Noli_PBS = open('PBS_.sh','r')
    raw_PBS = raw_Noli_PBS.readlines()
    sh="/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh"
    pbs_n="#PBS -N "
    
    Change_A = (A*100 - 99)
    plus_A = (A*100)
    str_A=str(Change_A)
    str_plus_A=str(plus_A)
    sh_num = sh + ' ' + str_A
    pbs_n_num = pbs_n + '' + str_A +'-'+ str_plus_A
    change_PBS.append(raw_PBS[0])
    change_PBS.append(raw_PBS[1])
    change_PBS.append(raw_PBS[2])
    change_PBS.append(raw_PBS[3])
    change_PBS.append(raw_PBS[4])
    change_PBS.append(raw_PBS[5])
    change_PBS.append(raw_PBS[6])
    change_PBS.append(raw_PBS[7])
    change_PBS.append(pbs_n_num)
    change_PBS.append(raw_PBS[9])
    change_PBS.append(raw_PBS[10])
    change_PBS.append(raw_PBS[11])
    change_PBS.append(raw_PBS[12])
    change_PBS.append(raw_PBS[13])
    change_PBS.append(sh_num)
    print(change_PBS)
    result = open(b,'w')
    result.writelines(change_PBS)
    change_PBS=[]
    #raw_PBS.replace("Change",A)
    b=''
# Out:
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 1-100', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 1']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 101-200', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 101']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 201-300', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 201']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 301-400', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 301']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 401-500', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 401']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 501-600', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 501']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 601-700', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 601']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 701-800', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 701']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 801-900', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 801']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 901-1000', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 901']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 1001-1100', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 1001']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 1101-1200', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 1101']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 1201-1300', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 1201']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 1301-1400', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 1301']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 1401-1500', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 1401']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 1501-1600', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 1501']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 1601-1700', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 1601']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 1701-1800', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 1701']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 1801-1900', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 1801']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 1901-2000', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 1901']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 2001-2100', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 2001']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 2101-2200', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 2101']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 2201-2300', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 2201']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 2301-2400', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 2301']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 2401-2500', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 2401']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 2501-2600', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 2501']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 2601-2700', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 2601']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 2701-2800', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 2701']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 2801-2900', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 2801']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 2901-3000', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 2901']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 3001-3100', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 3001']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 3101-3200', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 3101']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 3201-3300', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 3201']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 3301-3400', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 3301']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 3401-3500', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 3401']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 3501-3600', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 3501']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 3601-3700', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 3601']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 3701-3800', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 3701']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 3801-3900', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 3801']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 3901-4000', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 3901']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 4001-4100', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 4001']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 4101-4200', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 4101']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 4201-4300', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 4201']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 4301-4400', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 4301']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 4401-4500', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 4401']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 4501-4600', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 4501']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 4601-4700', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 4601']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 4701-4800', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 4701']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 4801-4900', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 4801']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 4901-5000', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 4901']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 5001-5100', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 5001']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 5101-5200', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 5101']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 5201-5300', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 5201']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 5301-5400', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 5301']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 5401-5500', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 5401']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 5501-5600', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 5501']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 5601-5700', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 5601']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 5701-5800', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 5701']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 5801-5900', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 5801']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 5901-6000', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 5901']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 6001-6100', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 6001']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 6101-6200', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 6101']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 6201-6300', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 6201']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 6301-6400', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 6301']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 6401-6500', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 6401']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 6501-6600', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 6501']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 6601-6700', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 6601']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 6701-6800', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 6701']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 6801-6900', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 6801']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 6901-7000', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 6901']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 7001-7100', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 7001']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 7101-7200', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 7101']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 7201-7300', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 7201']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 7301-7400', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 7301']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 7401-7500', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 7401']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 7501-7600', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 7501']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 7601-7700', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 7601']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 7701-7800', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 7701']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 7801-7900', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 7801']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 7901-8000', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 7901']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 8001-8100', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 8001']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 8101-8200', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 8101']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 8201-8300', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 8201']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 8301-8400', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 8301']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 8401-8500', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 8401']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 8501-8600', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 8501']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 8601-8700', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 8601']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 8701-8800', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 8701']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 8801-8900', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 8801']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 8901-9000', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 8901']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 9001-9100', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 9001']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 9101-9200', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 9101']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 9201-9300', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 9201']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 9301-9400', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 9301']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 9401-9500', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 9401']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 9501-9600', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 9501']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 9601-9700', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 9601']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 9701-9800', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 9701']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 9801-9900', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 9801']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 9901-10000', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 9901']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 10001-10100', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', '/scratch/x1997a11/GWAS/pdxen_AD/Code_folder/plink_permutation/repeat_check.sh 10001']

# %%
a=[]
b=''
for A in range(1,17):
    a.append("PBS_flat")
    a.append(str(A))
    a.append(".sh")
    b += ''.join(a)
    a=[]
    change_PBS=[]
    raw_Noli_PBS = open('PBS_flat.sh','r')
    raw_PBS = raw_Noli_PBS.readlines()
    sh="sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh "
    pbs_n="#PBS -N "
    
    Change_A = (A*100 + 9276)
    plus_A = (A*100 + 9276 + 99)
    str_A=str(Change_A)
    str_plus_A=str(plus_A)
    sh_num = sh + ' ' + str_A
    pbs_n_num = pbs_n + '' + str_A +'-'+ str_plus_A
    change_PBS.append(raw_PBS[0])
    change_PBS.append(raw_PBS[1])
    change_PBS.append(raw_PBS[2])
    change_PBS.append(raw_PBS[3])
    change_PBS.append(raw_PBS[4])
    change_PBS.append(raw_PBS[5])
    change_PBS.append(raw_PBS[6])
    change_PBS.append(raw_PBS[7])
    change_PBS.append(pbs_n_num)
    change_PBS.append(raw_PBS[9])
    change_PBS.append(raw_PBS[10])
    change_PBS.append(raw_PBS[11])
    change_PBS.append(raw_PBS[12])
    change_PBS.append(raw_PBS[13])
    change_PBS.append(sh_num)
    print(change_PBS)
    result = open(b,'w')
    result.writelines(change_PBS)
    change_PBS=[]
    #raw_PBS.replace("Change",A)
    b=''
# Out:
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q flat\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 9376-9475', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  9376']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q flat\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 9476-9575', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  9476']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q flat\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 9576-9675', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  9576']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q flat\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 9676-9775', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  9676']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q flat\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 9776-9875', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  9776']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q flat\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 9876-9975', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  9876']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q flat\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 9976-10075', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  9976']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q flat\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 10076-10175', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  10076']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q flat\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 10176-10275', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  10176']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q flat\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 10276-10375', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  10276']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q flat\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 10376-10475', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  10376']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q flat\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 10476-10575', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  10476']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q flat\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 10576-10675', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  10576']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q flat\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 10676-10775', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  10676']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q flat\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 10776-10875', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  10776']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q flat\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 10876-10975', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  10876']
