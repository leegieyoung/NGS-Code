# %%
raw_list = open('echo.txt','r')
raw_list_echo = raw_list.readlines()
raw_list_echo
# Out:
# ['sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh 1 44\n',
#  'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh 45 88\n',
#  'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh 89 132\n',
#  'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh 133 176\n',
#  'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh 177 220\n',
#  'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh 221 264\n',
#  'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh 265 308\n',
#  'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh 309 352\n',
#  'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh 353 396\n',
# ...

# %%
a=[]
b=''
for A in range(1,62):
    a.append("PBS_")
    a.append(str(A))
    a.append(".sh")
    b += ''.join(a)
    a=[]
    change_PBS=[]
    raw_Noli_PBS = open('PBS_.sh','r')
    raw_PBS = raw_Noli_PBS.readlines()
    sh="sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh "
    pbs_n="#PBS -N "
    
    Change_A = (A*100 + 3276)
    plus_A = (A*100 + 3276 + 99)
    str_A=str(Change_A)
    str_plus_A=str(plus_A)
    sh_num = sh + ' ' + str_A
    pbs_n_num = pbs_n + '' + str_A +'-'+ str_plus_A
    change_PBS.append(raw_PBS[0])
    change_PBS.append(raw_PBS[1])
    change_PBS.append(raw_PBS[2])
    change_PBS.append(raw_PBS[3])
    change_PBS.append(raw_PBS[4])
    change_PBS.append(raw_PBS[5])
    change_PBS.append(raw_PBS[6])
    change_PBS.append(raw_PBS[7])
    change_PBS.append(pbs_n_num)
    change_PBS.append(raw_PBS[9])
    change_PBS.append(raw_PBS[10])
    change_PBS.append(raw_PBS[11])
    change_PBS.append(raw_PBS[12])
    change_PBS.append(raw_PBS[13])
    change_PBS.append(sh_num)
    print(change_PBS)
    result = open(b,'w')
    result.writelines(change_PBS)
    change_PBS=[]
    #raw_PBS.replace("Change",A)
    b=''
# Out:
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 3376-3475', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  3376']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 3476-3575', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  3476']
# ...

# %%
a=[]
b=''
for A in range(1,17):
    a.append("PBS_flat")
    a.append(str(A))
    a.append(".sh")
    b += ''.join(a)
    a=[]
    change_PBS=[]
    raw_Noli_PBS = open('PBS_flat.sh','r')
    raw_PBS = raw_Noli_PBS.readlines()
    sh="sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh "
    pbs_n="#PBS -N "
    
    Change_A = (A*100 + 9276)
    plus_A = (A*100 + 9276 + 99)
    str_A=str(Change_A)
    str_plus_A=str(plus_A)
    sh_num = sh + ' ' + str_A
    pbs_n_num = pbs_n + '' + str_A +'-'+ str_plus_A
    change_PBS.append(raw_PBS[0])
    change_PBS.append(raw_PBS[1])
    change_PBS.append(raw_PBS[2])
    change_PBS.append(raw_PBS[3])
    change_PBS.append(raw_PBS[4])
    change_PBS.append(raw_PBS[5])
    change_PBS.append(raw_PBS[6])
    change_PBS.append(raw_PBS[7])
    change_PBS.append(pbs_n_num)
    change_PBS.append(raw_PBS[9])
    change_PBS.append(raw_PBS[10])
    change_PBS.append(raw_PBS[11])
    change_PBS.append(raw_PBS[12])
    change_PBS.append(raw_PBS[13])
    change_PBS.append(sh_num)
    print(change_PBS)
    result = open(b,'w')
    result.writelines(change_PBS)
    change_PBS=[]
    #raw_PBS.replace("Change",A)
    b=''
# Out:
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q flat\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 9376-9475', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  9376']
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q flat\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 9476-9575', '\n', 'module purge\n', 'module load python/3.7\n', '. /apps/applications/PYTHON/3.7/etc/profile.d/conda.sh\n', 'conda activate plink\n', 'sh /scratch/x1997a11/GWAS/pdxen_AD/Code_folder/repeat_check/repeat_check_start_end.sh  9476']
# ...

# %%
a=[]
b=''
for A in range(1,22):
    a.append("PBS_repeat_output")
    a.append(str(A))
    a.append(".sh")
    b += ''.join(a)
    a=[]
    change_PBS=[]
    raw_Noli_PBS = open('repeat_output.sh','r')
    raw_PBS = raw_Noli_PBS.readlines()
    sh="for A in $(seq"
    pbs_n="#PBS -N "
    
    Change_A = (A*500 - 499)
    plus_A = (A*500)
    str_A=str(Change_A)
    str_plus_A=str(plus_A)
    sh_num = sh + ' ' + str_A + ' '+  str_plus_A + ')' + '\n'
    pbs_n_num = pbs_n + '' + str_A +'-'+ str_plus_A + '\n'
    change_PBS.append(raw_PBS[0])
    change_PBS.append(raw_PBS[1])
    change_PBS.append(raw_PBS[2])
    change_PBS.append(raw_PBS[3])
    change_PBS.append(raw_PBS[4])
    change_PBS.append(raw_PBS[5])
    change_PBS.append(raw_PBS[6])
    change_PBS.append(raw_PBS[7])
    #change_PBS.append(raw_PBS[8])
    #change_PBS.append(raw_PBS[9])    
    change_PBS.append(pbs_n_num)
    change_PBS.append(sh_num)
    change_PBS.append(raw_PBS[10])
    change_PBS.append(raw_PBS[11])
    change_PBS.append(raw_PBS[12])
    change_PBS.append(raw_PBS[13])
    change_PBS.append(raw_PBS[14])
    change_PBS.append(raw_PBS[15])
    change_PBS.append(raw_PBS[16])
    change_PBS.append(raw_PBS[17])
    change_PBS.append(raw_PBS[18])
    change_PBS.append(raw_PBS[19])
    change_PBS.append(raw_PBS[20])
    
   
    print(change_PBS)
    result = open(b,'w')
    result.writelines(change_PBS)
    change_PBS=[]
    #raw_PBS.replace("Change",A)
    b=''
# Out:
# ['#!/bin/sh\n', '#PBS -V\n', '#PBS -q normal\n', '#PBS -A etc\n', '#PBS -l select=1:ncpus=68:mpiprocs=1:ompthreads=68\n', '#PBS -l walltime=48:00:00\n', '#PBS -o /scratch/x1997a11/PBS.OU\n', '#PBS -e /scratch/x1997a11/Error\n', '#PBS -N 1-500\n', 'for A in $(seq 1 500)\n', 'do\n', "echo 1:247614896_$A |  grep '1:247614896'  /scratch/x1997a11/GWAS/pdxen_AD/result_folder/repeat_check/plink_pphe/check$A/check${A}_assoc.assoc.logistic >> /scratch/x1997a11/GWAS/pdxen_AD/result_folder/repeat_check/rs11583410\n", '\n', "echo 1:247614617_$A | grep '1:247614617'  /scratch/x1997a11/GWAS/pdxen_AD/result_folder/repeat_check/plink_pphe/check$A/check${A}_assoc.assoc.logistic >> /scratch/x1997a11/GWAS/pdxen_AD/result_folder/repeat_check/rs4925663\n", '\n', "echo 20:4705718_$A | grep '20:4705718'  /scratch/x1997a11/GWAS/pdxen_AD/result_folder/repeat_check/plink_pphe/check$A/check${A}_assoc.assoc.logistic >> /scratch/x1997a11/GWAS/pdxen_AD/result_folder/repeat_check/rs2245220\n", '\n', "echo 20:47063
# ...
